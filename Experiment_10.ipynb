# %% [markdown]
# # **Experiment 10: Data Visualization**

# %% [markdown]
# ### Objective: Demonstrate various data visualization techniques using Matplotlib and Seaborn.

# %% [markdown]
# ### **Step 1: Import Libraries**

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Step 2: Load and Preprocess Data**

# %%
# Load the dataset
df = pd.read_csv('Titanic.csv')

# Handle missing values
df['Age'].fillna(df['Age'].mean(), inplace=True)
df.drop(columns=['Cabin'], inplace=True, errors='ignore')
# Out:
# C:\Users\amanr\AppData\Local\Temp\ipykernel_33000\1451095627.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %% [markdown]
# ### **Step 3: Data Visualization Examples**

# %% [markdown]
# #### 3.1: Age Distribution

# %%
# Histogram for Age
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #### 3.2: Survival Count

# %%
# Countplot for Survival
sns.countplot(x='Survived', data=df)
plt.title('Survival Count')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 3.3: Correlation Heatmap

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Generate the correlation heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
