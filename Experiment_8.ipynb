# %% [markdown]
# # **Experiment 8: Dimensionality Reduction using PCA**

# %% [markdown]
# ### Objective: Implement Principal Component Analysis (PCA) to reduce the dataset dimensions for visualization or feature extraction.

# %% [markdown]
# ## **Step 1: Preprocessing**

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Titanic.csv')
df.head()

# Handle missing values (e.g., fill missing 'Age' with mean and drop 'Cabin')
df['Age'].fillna(df['Age'].mean(), inplace=True)
df.drop(columns=['Cabin'], inplace=True, errors='ignore')

# Convert categorical data to numerical using one-hot encoding
df = pd.get_dummies(df, drop_first=True)

# Separate features and target
X = df.drop(columns=['Survived'], errors='ignore')  # Features
y = df['Survived']  # Target
# Out:
# C:\Users\amanr\AppData\Local\Temp\ipykernel_42168\188332771.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %% [markdown]
# ## **Step 2: Standardize Features**

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features for PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## **Step 3: Apply PCA**

# %%
from sklearn.decomposition import PCA

# Apply PCA to reduce to 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Display explained variance
print("Explained Variance by Components:", pca.explained_variance_ratio_)
# Out:
# Explained Variance by Components: [0.00241557 0.00232465]

# %% [markdown]
# ## **Step 4: Visualize the PCA Results**

# %%
import matplotlib.pyplot as plt

# Scatter plot for PCA components
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', alpha=0.8)
plt.title('PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Survived')
plt.show()
